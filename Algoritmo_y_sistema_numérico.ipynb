# %%
ALGORITMO Y SISTEMA NMERICO

# %% [markdown]
# En esta clase, exploramos los conceptos básicos de los algoritmos de programación y los sistemas numéricos.
#  Donde Aprendimos a diseñar algoritmos y entendimos los diferentes sistemas numericos utilizando la programacion y  Las matemáticas.
#
# Material de Clase
#
# *   Ver videos
# *   Apuntes en clases
#
# Sea ∩ conjunto
#
#  {A
# i
# ​
#  }
# n
#    i=1 tq A;⊆∩
#
# ∩ n i=1
# ​
#  A
# i
# ​
# ´{XE∩: XE∀iE´{1,N},XEA;}
#
# A∩B={XE∩XEA ʌ XEB}
#
#  A,⊆∩,A2⊆∩
#  Ai, iE{1N}
#
#  Ai,⊆∩
#
#  A∩B={XE∩XEA ʌ XEB}
#
#
# *   NEGACION
#
# P:"Todo elemento de A es par"-> ∀XEA,X es par
#
#    "Ningun elemento de A es par"
#
#    *Todo elemento de A es impar *->ƎXEA
#
#
# *  ∀X, P(X)
#
#
# *   ƎX,~P(X)
#
# P:∀nEN,ƎKN + q k>n
#
#
# ~:ƎnEN,∀kEn, k≤n
#
#
#
# ALGORITMO
#
#
#
# 1.   inicio
#
# 2.   Leer la nota asignatura 1. nota 1
# 3.   leer la nota asignatura 2. nota 2
#
# 4.  sumar nota 1 mas nota 2,el resultado:suma
# 5.   Dividir a suma entre 2, el resultado sera el promedio
#
# 6.   Escribir el promedio de las dos asignaturas.
# 7.   Fin
#  Esto nos muesta que es un proceso de entrada y salida
#
#  (E/P/S)
#
#
# *  ( E)LECTURA ( Lea) L
# *   (P)CALCULO       Area-> L*L
# *  (S) ESTRUCTURA ( Escriba) ("El area del cuadrado es.",area)
#
#
#
#
# *   BUSQUEDA BINARIA y lineal.
#
# ![WhatsApp Image 2024-06-30 at 12.46.05 PM.jpeg](data:image/jpeg;base64,...)
#
#  Teoria de la informacion
#
# SHANNON pensaba que la informacion se devia medir como la cantidad de preguntas de si o no y a cada respuesta la llamo (bit)
#
# ejemplo
#
# ¿ cual es mi planeta favorito del sistema solar ?
#
# la respuesta esta entre 8 candidatos
#
# pero en este caso
#
# ¿El nomre termina en o?
#
# ¿Tiene aspecto azulado?
#
# ¿ Tiene anillos?
#
# tres pregutas y adivinado
#
#
#
# *   SISTEMAS NUMERICOS
#
# Numeros naturales
#
# N={0,1,2,3,....}     n->n+1
#
# (N,≤) ∀a,b E N, a≤b
#                 o
#                 a>b
#
# (N,+) ∀ a,b E N Ǝ C E, +q c= a+b
#
# sea a,bE N
#
# a+b=?
#
# hablando de un ejemplo de una ganja y las obejas
#
#  a+?= b
#
#  20 + ? =50
#
#  50+?=20
#
#  Sea n E N
#
#  Considera n+ ?=0
#
#  SIMETRICIACION CON RESPECTO A LA SUMA
#
#  Considera n+?=0
#  n+(-n)=0
#
#  N,≤,+,x
#
#  ∀ a,b E N, Ǝ E N
#
#  +q C=ab
#
#  ab=?
#
#  a?=b
#
#  5*?=50
#
#  ?=50/5
#
#  50/5
#
#  N ⊆ Z ⊆ R
#
#
#  Q={n/m: nE Z, m E N}
#
#
#  Q=  2X=10
#
#  X*X=10->x2=10
#
#  X2 =25
#
#  X= -5
#
#  X=5
